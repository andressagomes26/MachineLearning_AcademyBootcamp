# %% [markdown]
# ### Importações

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
from skimage import exposure

# %% [markdown]
# ### Aguçamento
#
# **7.3	FILTRO	MÁSCARA	DE	DESAGUÇAMENTO**

# %%
imgOriginal = cv2.imread('sunrise136.jpg', 1)
imgSuavizada = cv2.GaussianBlur(imgOriginal, (13,13), 3)
imgDetalhes = 3 * cv2.subtract(imgOriginal, imgSuavizada)
imgRealcada = cv2.add(imgOriginal, imgDetalhes)

imgOriginal = imgOriginal[::3,::3] # Diminui a imagem 
imgSuavizada = imgSuavizada[::3,::3] # Diminui a imagem 
imgDetalhes = imgDetalhes[::3,::3] # Diminui a imagem 
imgRealcada = imgRealcada[::3,::3] # Diminui a imagem

cv2.imshow("Original", imgOriginal)
cv2.imshow("Suavizada", imgSuavizada)
#cv2.imshow("Bordas", imgDetalhes)
cv2.imshow("Realcada", imgRealcada)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ***sunrise172.jpg***
#
# ![image-5.png](attachment:image-5.png)
#
# ***sunrise346.jpg***
#
# ![image-6.png](attachment:image-6.png)
#
# ***sunrise146.jpg***
#
# ![image-7.png](attachment:image-7.png)

# %%
imgOriginal = cv2.imread('sunrise305.jpg', 1)
imgSuavizada = cv2.GaussianBlur(imgOriginal, (13,13), 3)
imgDetalhes = 3 * cv2.subtract(imgOriginal, imgSuavizada)
imgRealcada = cv2.add(imgOriginal, imgDetalhes)

cv2.imshow("Original", imgOriginal)
cv2.imshow("Suavizada", imgSuavizada)
cv2.imshow("Bordas", imgDetalhes)
cv2.imshow("Realcada", imgRealcada)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
imgOriginal = cv2.imread('sunrise305.jpg', 1)
imgSuavizada = cv2.GaussianBlur(imgOriginal, (13,13), 3)
imgDetalhes = 3 * cv2.subtract(imgOriginal, imgSuavizada)
imgRealcada = cv2.add(imgOriginal, imgDetalhes)

size = (256, 256)
imgOriginal = cv2.resize(imgOriginal, size, interpolation = cv2.INTER_AREA)
imgSuavizada = cv2.resize(imgSuavizada, size, interpolation = cv2.INTER_AREA)
imgDetalhes = cv2.resize(imgDetalhes, size, interpolation = cv2.INTER_AREA)
imgRealcada = cv2.resize(imgRealcada, size, interpolation = cv2.INTER_AREA)

cv2.imshow("Original", imgOriginal)
cv2.imwrite("sunrise305Original.jpg", imgOriginal)

cv2.imshow("Suavizada", imgSuavizada)
cv2.imwrite("sunrise305Suavizada.jpg", imgSuavizada)

cv2.imshow("Realcada", imgRealcada)
cv2.imwrite("sunrise305Realcada.jpg", imgRealcada)

cv2.waitKey(0)
cv2.destroyAllWindows()
